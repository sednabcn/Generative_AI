# %% [markdown]
# TAsk:Identify data source in Tableau and replicate in Power BI

# %% [markdown]
# Identifying the data source in Tableau and replicating it in Power BI involves understanding the type of data connection, data structure, and any transformations applied. Here are general steps to guide you through the process:

# %%
! pip install opencv-python

# %%
import cv2
from google.colab.patches import cv2_imshow

# %% [markdown]
# Identify data source in Tableau

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with open('/content/drive/My Drive/foo.txt', 'w') as f:
  f.write('Hello Google Drive!')
# !cat /content/drive/My\ Drive/foo.txt
# Out:
# Hello Google Drive!

# %%
! cd /content/drive/My\ Drive/Colab_2024
! cp /content/drive/My\ Drive/Colab_2024/*.png /content/
! ls -all
# Out:
# total 272
# drwxr-xr-x 1 root root   4096 Feb 23 20:45  .
# drwxr-xr-x 1 root root   4096 Feb 23 19:28  ..
# drwxr-xr-x 4 root root   4096 Feb 22 14:24  .config
# drwx------ 5 root root   4096 Feb 23 20:29  drive
# -rw------- 1 root root  26670 Feb 23 20:46  Figure_pandas.png
# -rw------- 1 root root  32115 Feb 23 20:46  Figure_sigma.png
# -rw------- 1 root root  45959 Feb 23 20:46  interpolated.png
# -rw-r--r-- 1 root root   9154 Feb 23 19:36  iris.twbx
# -rw------- 1 root root 113060 Feb 23 20:46  PowerBI-flowers.png
# drwxr-xr-x 1 root root   4096 Feb 22 14:24  sample_data
# -rw------- 1 root root  16544 Feb 23 20:46 'Sheet 6.png'

# %% [markdown]
# 1    Open the Tableau Workbook:
#         Open the Tableau workbook that contains the data you want to replicate in Power BI.

# %% [markdown]
# Iris Dataset

# %% [markdown]
# 2    Check Data Connection:
#         In Tableau, check the data connection by navigating to the "Data Source" tab or by clicking on the data source pane on the left side of the screen.
#         Note the type of data connection (e.g., Excel, SQL Server, CSV).

# %% [markdown]
# Excel: iris.xlsx
# CSV  : iris.csv

# %% [markdown]
# 3    Check Data Structure:
#         Explore the data structure by looking at the fields and their data types in Tableau.

# %% [markdown]
# Tables: 1 Table
# Text(string): "variety": dimensions
# Numeric Data Types: columns=["sepal.length","sepal.width","petal.length","petal.width"]

# %% [markdown]
# 4    Check Applied Transformations:
#         Identify any data transformations or calculations applied in Tableau, such as filters, calculated fields, or aggregations.

# %% [markdown]
# sepal_sum = [sepal.length]+[sepal.width]
# petal_sum = [petal.length]+ [petal.width]

# %%
# Open the Tableau image.
img = cv2.imread("/content/Sheet 6.png")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=565x600>

# %%
# Open a Samg image.
img = cv2.imread("/content/Figure_sigma.png")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=717x432>

# %% [markdown]
#      Replicating in Power BI:

# %% [markdown]
# 5    Install Power BI Desktop:
#         If you haven't already, download and install Power BI Desktop from the Microsoft website.
#
# 6    Open Power BI Desktop:
#         Open Power BI Desktop and create a new report.
#
# 7    Add Data Source:
#         Click on "Get Data" in the Home tab and select the appropriate data source type (e.g., Excel, SQL Server, CSV) based on the Tableau data source.
#
# 8    Connect to Data:
#         Provide the necessary connection details and credentials to connect to the data source.
#
# 9    Load Data:
#         Load the data into Power BI by selecting the appropriate tables or views.
#
# 10    Check Data Structure:
#         Explore the fields and their data types in Power BI to ensure consistency with Tableau.
#
# 11    Apply Transformations:
#         Replicate any data transformations or calculations applied in Tableau using Power BI's Power Query Editor.
#
# 12    Create Visualizations:
#         Once the data is loaded and transformed, create visualizations in Power BI to replicate the analysis done in Tableau.

# %%
# Open the PowerBI image.
img = cv2.imread("/content/PowerBI-flowers.png")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1316x1040>

# %% [markdown]
# Considerations:
#
#     Data Source Compatibility:
#     Ensure that the data source type is supported in both Tableau and Power BI.
#
#     Custom Calculations:
#     Recreate any custom calculations or calculated fields from Tableau in Power BI.
#
#     Data Refresh:
#     Set up data refresh schedules in Power BI Service if the data is dynamic and needs to be updated regularly.
#
# By following these steps, you should be able to identify the data source in Tableau and replicate the analysis in Power BI. Keep in mind that certain advanced features or visualizations might have differences between the two tools, so some adjustments may be necessary.
